# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Big_mart.csv")

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df['Outlet_Size'].fillna(value='Medium', inplace=True)
df['Item_Fat_Content'].replace(['Regular','Low Fat','reg','low fat'],['R','LF','R','LF'],inplace=True)
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace=True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000               LF         0.016047
# 1              DRC01     5.920000                R         0.019278
# 2              FDN15    17.500000               LF         0.016760
# 3              FDX07    19.200000                R         0.000000
# 4              NCD19     8.930000               LF         0.000000
# 5              FDP36    10.395000                R         0.000000
# 6              FDO10    13.650000                R         0.012741
# 7              FDP10    12.857645               LF         0.127470
# 8              FDH17    16.200000                R         0.016687
# 9              FDU28    19.200000                R         0.094450
# 10             FDY07    11.800000               LF         0.000000
# 11             FDA03    18.500000                R         0.045464
# 12             FDX32    15.100000                R         0.100014
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=8523, step=1),
#  Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#         'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#         'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#         'Outlet_Type', 'Item_Outlet_Sales'],
#        dtype='object')]

# %%
df.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000               LF         0.016047
# 1            DRC01     5.920000                R         0.019278
# 2            FDN15    17.500000               LF         0.016760
# 3            FDX07    19.200000                R         0.000000
# 4            NCD19     8.930000               LF         0.000000
# 5            FDP36    10.395000                R         0.000000
# 6            FDO10    13.650000                R         0.012741
# 7            FDP10    12.857645               LF         0.127470
# 8            FDH17    16.200000                R         0.016687
# 9            FDU28    19.200000                R         0.094450
# 10           FDY07    11.800000               LF         0.000000
# 11           FDA03    18.500000                R         0.045464
# 12           FDX32    15.100000                R         0.100014
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
sns.pairplot(df,hue='Item_Type',size=3).add_legend()
plt.show()

# %%
sns.pairplot(df,hue='Outlet_Size',size=3).add_legend()
plt.show()

# %%
sns.FacetGrid(df,hue='Outlet_Size',size=5).map(sns.distplot,'Item_Weight').add_legend();
plt.show()
# Out:
# C:\Users\AmitPc\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.swarmplot(x='Outlet_Size',y='Item_Weight',data=df)
plt.show()

# %%
d=df.head(20)
d
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000               LF         0.016047
# 1            DRC01     5.920000                R         0.019278
# 2            FDN15    17.500000               LF         0.016760
# 3            FDX07    19.200000                R         0.000000
# 4            NCD19     8.930000               LF         0.000000
# 5            FDP36    10.395000                R         0.000000
# 6            FDO10    13.650000                R         0.012741
# 7            FDP10    12.857645               LF         0.127470
# 8            FDH17    16.200000                R         0.016687
# 9            FDU28    19.200000                R         0.094450
# 10           FDY07    11.800000               LF         0.000000
# 11           FDA03    18.500000                R         0.045464
# 12           FDX32    15.100000                R         0.100014
# ...

# %%
d1 = d[['Item_Weight', 'Item_Fat_Content','Item_MRP','Item_Outlet_Sales']]
d1
# Out:
#     Item_Weight Item_Fat_Content  Item_MRP  Item_Outlet_Sales
# 0      9.300000               LF  249.8092          3735.1380
# 1      5.920000                R   48.2692           443.4228
# 2     17.500000               LF  141.6180          2097.2700
# 3     19.200000                R  182.0950           732.3800
# 4      8.930000               LF   53.8614           994.7052
# 5     10.395000                R   51.4008           556.6088
# 6     13.650000                R   57.6588           343.5528
# 7     12.857645               LF  107.7622          4022.7636
# 8     16.200000                R   96.9726          1076.5986
# 9     19.200000                R  187.8214          4710.5350
# 10    11.800000               LF   45.5402          1516.0266
# 11    18.500000                R  144.1102          2187.1530
# 12    15.100000                R  145.4786          1589.2646
# 13    17.600000                R  119.6782          2145.2076
# ...

# %%
x=d1.iloc[:,:-1].values
y=d1.iloc[:,3].values

# %%
print(pd.DataFrame(x))
print(pd.DataFrame(y))
# Out:
#           0   1        2
# 0       9.3  LF  249.809
# 1      5.92   R  48.2692
# 2      17.5  LF  141.618
# 3      19.2   R  182.095
# 4      8.93  LF  53.8614
# 5    10.395   R  51.4008
# 6     13.65   R  57.6588
# 7   12.8576  LF  107.762
# 8      16.2   R  96.9726
# 9      19.2   R  187.821
# 10     11.8  LF  45.5402
# 11     18.5   R   144.11
# 12     15.1   R  145.479
# 13     17.6   R  119.678
# 14    16.35  LF  196.443
# 15        9   R  56.3614
# 16     11.8  LF  115.349
# 17        9   R  54.3614
# 18  12.8576  LF  113.283
# 19    13.35  LF  230.535
#             0
# 0   3735.1380
# 1    443.4228
# 2   2097.2700
# 3    732.3800
# 4    994.7052
# 5    556.6088
# 6    343.5528
# 7   4022.7636
# 8   1076.5986
# 9   4710.5350
# 10  1516.0266
# 11  2187.1530
# 12  1589.2646
# 13  2145.2076
# 14  1977.4260
# 15  1547.3192
# 16  1621.8888
# 17   718.3982
# 18  2303.6680
# 19  2748.4224

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder=LabelEncoder()
x[:,1]=labelencoder.fit_transform(x[:,1])
print(pd.DataFrame(x))
# Out:
#           0  1        2
# 0       9.3  0  249.809
# 1      5.92  1  48.2692
# 2      17.5  0  141.618
# 3      19.2  1  182.095
# 4      8.93  0  53.8614
# 5    10.395  1  51.4008
# 6     13.65  1  57.6588
# 7   12.8576  0  107.762
# 8      16.2  1  96.9726
# 9      19.2  1  187.821
# 10     11.8  0  45.5402
# 11     18.5  1   144.11
# 12     15.1  1  145.479
# 13     17.6  1  119.678
# 14    16.35  0  196.443
# 15        9  1  56.3614
# 16     11.8  0  115.349
# 17        9  1  54.3614
# 18  12.8576  0  113.283
# 19    13.35  0  230.535

# %%
onehotencoder=OneHotEncoder(categorical_features=[1])
x=onehotencoder.fit_transform(x).toarray()
print(pd.DataFrame(x))
# Out:
#       0    1          2         3
# 0   1.0  0.0   9.300000  249.8092
# 1   0.0  1.0   5.920000   48.2692
# 2   1.0  0.0  17.500000  141.6180
# 3   0.0  1.0  19.200000  182.0950
# 4   1.0  0.0   8.930000   53.8614
# 5   0.0  1.0  10.395000   51.4008
# 6   0.0  1.0  13.650000   57.6588
# 7   1.0  0.0  12.857645  107.7622
# 8   0.0  1.0  16.200000   96.9726
# 9   0.0  1.0  19.200000  187.8214
# 10  1.0  0.0  11.800000   45.5402
# 11  0.0  1.0  18.500000  144.1102
# 12  0.0  1.0  15.100000  145.4786
# 13  0.0  1.0  17.600000  119.6782
# 14  1.0  0.0  16.350000  196.4426
# 15  0.0  1.0   9.000000   56.3614
# 16  1.0  0.0  11.800000  115.3492
# 17  0.0  1.0   9.000000   54.3614
# 18  1.0  0.0  12.857645  113.2834
# 19  1.0  0.0  13.350000  230.5352

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=regressor.predict(x_test)
print(pd.DataFrame({'Actual':list(y_test),'Predicted':list(y_pred)}))
# Out:
#       Actual    Predicted
# 0  2303.6680  2077.487765
# 1   443.4228  1098.520960
# 2  2748.4224  3329.030105
# 3  1076.5986  1549.866348
# 4  1516.0266  1359.656441
# 5   718.3982  1142.778890
# 6   343.5528  1146.449406
# 7  2145.2076  1783.353608

# %%
from sklearn import metrics
print("Mean Absolute Error:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error:",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Absolute Error:",np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 460.08191176
# Mean Squared Error: 252691.329225
# Root Mean Absolute Error: 21.4495200823
