# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Big_mart.csv")

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df['Outlet_Size'].fillna(value='Medium', inplace=True)
df['Item_Fat_Content'].replace(['Regular','Low Fat','reg','low fat'],['R','LF','R','LF'],inplace=True)
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace=True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000               LF         0.016047
# 1              DRC01     5.920000                R         0.019278
# 2              FDN15    17.500000               LF         0.016760
# 3              FDX07    19.200000                R         0.000000
# 4              NCD19     8.930000               LF         0.000000
# 5              FDP36    10.395000                R         0.000000
# 6              FDO10    13.650000                R         0.012741
# 7              FDP10    12.857645               LF         0.127470
# 8              FDH17    16.200000                R         0.016687
# 9              FDU28    19.200000                R         0.094450
# 10             FDY07    11.800000               LF         0.000000
# 11             FDA03    18.500000                R         0.045464
# 12             FDX32    15.100000                R         0.100014
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=8523, step=1),
#  Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#         'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#         'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#         'Outlet_Type', 'Item_Outlet_Sales'],
#        dtype='object')]

# %%
d=df.head(20)

# %%
d1 = d[['Item_Weight','Item_MRP','Item_Outlet_Sales','Item_Fat_Content']]
d1
# Out:
#     Item_Weight  Item_MRP  Item_Outlet_Sales Item_Fat_Content
# 0      9.300000  249.8092          3735.1380               LF
# 1      5.920000   48.2692           443.4228                R
# 2     17.500000  141.6180          2097.2700               LF
# 3     19.200000  182.0950           732.3800                R
# 4      8.930000   53.8614           994.7052               LF
# 5     10.395000   51.4008           556.6088                R
# 6     13.650000   57.6588           343.5528                R
# 7     12.857645  107.7622          4022.7636               LF
# 8     16.200000   96.9726          1076.5986                R
# 9     19.200000  187.8214          4710.5350                R
# 10    11.800000   45.5402          1516.0266               LF
# 11    18.500000  144.1102          2187.1530                R
# 12    15.100000  145.4786          1589.2646                R
# 13    17.600000  119.6782          2145.2076                R
# ...

# %%
x=d1.iloc[:,:-1].values
y=d1.iloc[:,3].values
print(pd.DataFrame(x))
print(pd.DataFrame(y))
# Out:
#             0         1          2
# 0    9.300000  249.8092  3735.1380
# 1    5.920000   48.2692   443.4228
# 2   17.500000  141.6180  2097.2700
# 3   19.200000  182.0950   732.3800
# 4    8.930000   53.8614   994.7052
# 5   10.395000   51.4008   556.6088
# 6   13.650000   57.6588   343.5528
# 7   12.857645  107.7622  4022.7636
# 8   16.200000   96.9726  1076.5986
# 9   19.200000  187.8214  4710.5350
# 10  11.800000   45.5402  1516.0266
# 11  18.500000  144.1102  2187.1530
# 12  15.100000  145.4786  1589.2646
# 13  17.600000  119.6782  2145.2076
# 14  16.350000  196.4426  1977.4260
# 15   9.000000   56.3614  1547.3192
# 16  11.800000  115.3492  1621.8888
# 17   9.000000   54.3614   718.3982
# 18  12.857645  113.2834  2303.6680
# 19  13.350000  230.5352  2748.4224
#      0
# 0   LF
# 1    R
# 2   LF
# 3    R
# 4   LF
# 5    R
# 6    R
# 7   LF
# 8    R
# 9    R
# 10  LF
# 11   R
# 12   R
# 13   R
# 14  LF
# 15   R
# 16  LF
# 17   R
# 18  LF
# 19  LF

# %%
y.shape
# Out:
# (20,)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder=LabelEncoder()
y=labelencoder.fit_transform(y)
print(pd.DataFrame(y))
# Out:
#     0
# 0   0
# 1   1
# 2   0
# 3   1
# 4   0
# 5   1
# 6   1
# 7   0
# 8   1
# 9   1
# 10  0
# 11  1
# 12  1
# 13  1
# 14  0
# 15  1
# 16  0
# 17  1
# 18  0
# 19  0

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred=classifier.predict(x_test)
print(pd.DataFrame({'Actual':list(y_test),'Predicted':list(y_pred)}))
# Out:
#    Actual  Predicted
# 0       0          1
# 1       1          1
# 2       0          0
# 3       1          1
# 4       0          1
# 5       1          1
# 6       1          1
# 7       1          1
# 8       0          1
# 9       0          1

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1, 4],
#        [0, 5]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.59999999999999998
